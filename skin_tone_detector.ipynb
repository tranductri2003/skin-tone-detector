# %% [markdown]
# # SKIN_TONE_DETECTOR

# %% [markdown]
# ## IMPORT LIBRARY

# %%
import cv2
import allotSkinTone
import skin_detector
from sklearn.cluster import KMeans
import csv
from collections import defaultdict 
import matplotlib.pyplot as plt
import time
import logging
import cv2
import numpy
import os
from IPython.display import display, Image
import cv2
import numpy as np
import random

# %% [markdown]
# ## SKIN DETECTOR

# %%
def find_images(path, recursive=False, ignore=True):
    if os.path.isfile(path):
        yield path
    elif os.path.isdir(path):
        assert os.path.isdir(path), 'FileIO - get_images: Directory does not exist'
        assert isinstance(recursive, bool), 'FileIO - get_images: recursive must be a boolean variable'
        ext, result = ['png', 'jpg', 'jpeg'], []
        for path_a in os.listdir(path):
            path_a = path + '/' + path_a
            if os.path.isdir(path_a) and recursive:
                for path_b in find_images(path_a):
                    yield path_b
            check_a = path_a.split('.')[-1] in ext
            check_b = ignore or ('-' not in path_a.split('/')[-1])
            if check_a and check_b:
                yield path_a
    else:
        raise ValueError('error! path is not a valid path or directory')


def display(title, img, max_size=200000):
    assert isinstance(img, numpy.ndarray), 'img must be a numpy array'
    assert isinstance(title, str), 'title must be a string'
    scale = numpy.sqrt(min(1.0, float(max_size) / (img.shape[0] * img.shape[1])))
    shape = (int(scale * img.shape[1]), int(scale * img.shape[0]))
    img = cv2.resize(img, shape)
    cv2.imshow(title, img)
    
    

logger = logging.getLogger('main')


def get_hsv_mask(img, debug=False):
    assert isinstance(img, numpy.ndarray), 'image must be a numpy array'
    assert img.ndim == 3, 'skin detection can only work on color images'
    logger.debug('getting hsv mask')

    lower_thresh = numpy.array([0, 50, 0], dtype=numpy.uint8)
    upper_thresh = numpy.array([120, 150, 255], dtype=numpy.uint8)
    img_hsv = cv2.cvtColor(img, cv2.COLOR_RGB2HSV)
    msk_hsv = cv2.inRange(img_hsv, lower_thresh, upper_thresh)

    msk_hsv[msk_hsv < 128] = 0
    msk_hsv[msk_hsv >= 128] = 1

    if debug:
        display('input', img)
        display('mask_hsv', msk_hsv)

    return msk_hsv.astype(float)


def get_rgb_mask(img, debug=False):
    assert isinstance(img, numpy.ndarray), 'image must be a numpy array'
    assert img.ndim == 3, 'skin detection can only work on color images'
    logger.debug('getting rgb mask')

    lower_thresh = numpy.array([45, 52, 108], dtype=numpy.uint8)
    upper_thresh = numpy.array([255, 255, 255], dtype=numpy.uint8)

    mask_a = cv2.inRange(img, lower_thresh, upper_thresh)
    mask_b = 255 * ((img[:, :, 2] - img[:, :, 1]) / 20)
    mask_c = 255 * ((numpy.max(img, axis=2) - numpy.min(img, axis=2)) / 20)
    # msk_rgb = cv2.bitwise_and(mask_c, cv2.bitwise_and(mask_a, mask_b))
    mask_d = numpy.bitwise_and(numpy.uint64(mask_a), numpy.uint64(mask_b))
    msk_rgb = numpy.bitwise_and(numpy.uint64(mask_c), numpy.uint64(mask_d))

    msk_rgb[msk_rgb < 128] = 0
    msk_rgb[msk_rgb >= 128] = 1

    if debug:
        display('input', img)
        display('mask_rgb', msk_rgb)

    return msk_rgb.astype(float)


def get_ycrcb_mask(img, debug=False):
    assert isinstance(img, numpy.ndarray), 'image must be a numpy array'
    assert img.ndim == 3, 'skin detection can only work on color images'
    logger.debug('getting ycrcb mask')

    lower_thresh = numpy.array([90, 100, 130], dtype=numpy.uint8)
    upper_thresh = numpy.array([230, 120, 180], dtype=numpy.uint8)

    img_ycrcb = cv2.cvtColor(img, cv2.COLOR_RGB2YCR_CB)
    msk_ycrcb = cv2.inRange(img_ycrcb, lower_thresh, upper_thresh)

    msk_ycrcb[msk_ycrcb < 128] = 0
    msk_ycrcb[msk_ycrcb >= 128] = 1

    if debug:
        display('input', img)
        display('mask_ycrcb', msk_ycrcb)

    return msk_ycrcb.astype(float)


def grab_cut_mask(img_col, mask, debug=False):
    assert isinstance(img_col, numpy.ndarray), 'image must be a numpy array'
    assert isinstance(mask, numpy.ndarray), 'mask must be a numpy array'
    assert img_col.ndim == 3, 'skin detection can only work on color images'
    assert mask.ndim == 2, 'mask must be 2D'

    kernel = numpy.ones((50, 50), numpy.float32) / (50 * 50)
    dst = cv2.filter2D(mask, -1, kernel)
    dst[dst != 0] = 255
    free = numpy.array(cv2.bitwise_not(dst), dtype=numpy.uint8)

    if debug:
        display('not skin', free)
        display('grabcut input', mask)

    grab_mask = numpy.zeros(mask.shape, dtype=numpy.uint8)
    grab_mask[:, :] = 2
    grab_mask[mask == 255] = 1
    grab_mask[free == 255] = 0

    if numpy.unique(grab_mask).tolist() == [0, 1]:
        logger.debug('conducting grabcut')
        bgdModel = numpy.zeros((1, 65), numpy.float64)
        fgdModel = numpy.zeros((1, 65), numpy.float64)

        if img_col.size != 0:
            mask, bgdModel, fgdModel = cv2.grabCut(img_col, grab_mask, None, bgdModel, fgdModel, 5,
                                                   cv2.GC_INIT_WITH_MASK)
            mask = numpy.where((mask == 2) | (mask == 0), 0, 1).astype(numpy.uint8)
        else:
            logger.warning('img_col is empty')

    return mask


def closing(mask):
    assert isinstance(mask, numpy.ndarray), 'mask must be a numpy array'
    assert mask.ndim == 2, 'mask must be a greyscale image'
    logger.debug("closing mask of shape {0}".format(mask.shape))

    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (5, 5))
    mask = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel)
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (3, 3))
    mask = cv2.morphologyEx(mask, cv2.MORPH_OPEN, kernel, iterations=2)

    return mask


def process(img, thresh=0.5, debug=False):
    assert isinstance(img, numpy.ndarray), 'image must be a numpy array'
    assert img.ndim == 3, 'skin detection can only work on color images'
    logger.debug("processing image of shape {0}".format(img.shape))

    mask_hsv = get_hsv_mask(img, debug=debug)
    mask_rgb = get_rgb_mask(img, debug=debug)
    mask_ycrcb = get_ycrcb_mask(img, debug=debug)
    
    n_masks = 3.0
    mask = (mask_hsv + mask_rgb + mask_ycrcb) / n_masks

    mask[mask < thresh] = 0.0
    mask[mask >= thresh] = 255.0
    logger.debug('{0}% of the image is skin'.format(int((100.0 / 255.0) * numpy.sum(mask) / mask.size)))

    mask = mask.astype(numpy.uint8)

    mask = closing(mask)
    mask = grab_cut_mask(img, mask, debug=debug)

    return mask
    

def show_skin_image(img, thresh=0.5, debug=False):
    assert isinstance(img, numpy.ndarray), 'image must be a numpy array'
    assert img.ndim == 3, 'skin detection can only work on color images'
    logger.debug("processing image of shape {0}".format(img.shape))

    mask_hsv = get_hsv_mask(img, debug=debug)
    mask_rgb = get_rgb_mask(img, debug=debug)
    mask_ycrcb = get_ycrcb_mask(img, debug=debug)
    
    n_masks = 3.0
    mask = (mask_hsv + mask_rgb + mask_ycrcb) / n_masks

    mask[mask < thresh] = 0.0
    mask[mask >= thresh] = 255.0
    logger.debug('{0}% of the image is skin'.format(int((100.0 / 255.0) * numpy.sum(mask) / mask.size)))

    mask = mask.astype(numpy.uint8)

    mask = closing(mask)
    mask = grab_cut_mask(img, mask, debug=debug)

    # Tạo ảnh mới với kích thước giống với ảnh đầu vào và màu trong suốt (đen hoặc màu alpha = 0)
    skin_image = numpy.zeros_like(img, dtype=numpy.uint8)

    # Cập nhật chỉ những phần có da từ ảnh gốc vào ảnh mới
    skin_image = cv2.bitwise_and(img, img, mask=mask)
    
    return skin_image

# %%
img_path = "359651.jpg"
image = cv2.imread(img_path)
skin_image = show_skin_image(image)

plt.imshow(skin_image)
plt.show()

# %% [markdown]
# ## K-MEAN TO FIND DOMINANT COLOR

# %%
def create_map_from_csv(file_path):
    result_map = {}
    
    with open(file_path, 'r') as csv_file:
        csv_reader = csv.reader(csv_file)
        
        for row in csv_reader:
            if len(row) >= 3:  # Đảm bảo có ít nhất 3 giá trị trên hàng
                key = row[0]
                value = row[-3]
                result_map[key] = value
                image_data.append(key)
    
    return result_map


csv_file_path = "D:\Code\BachKhoa\AI Hackathon\labels.csv"
image_data = []
label_map = create_map_from_csv(csv_file_path)
image_data = image_data[1:]
image_path = "D:\Code\BachKhoa\AI Hackathon\mnt\md0\projects\sami-hackathon\private\data"
count = 0
diffusion_matrix = defaultdict(lambda: defaultdict(lambda: 0))
random.shuffle(image_data)

# %%
def find_dominant_color(image, mask, n_colors=3):
    # Chuyển hình ảnh sang RGB
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # Dùng mặt nạ để lấy các vùng da trong hình ảnh
    skin_pixels = image_rgb[mask == 255]

    # Định hình lại skin_pixels thành một mảng 2D
    skin_pixels_2d = skin_pixels.reshape((-1, 3))

    # Áp dụng K-Means clustering
    kmeans = KMeans(n_clusters=n_colors, n_init=10)
    kmeans.fit(skin_pixels_2d)
    labels = kmeans.labels_
    
    # Đếm số lượng pixel cho mỗi cụm
    counts = np.bincount(labels)
    
    # Chọn cụm có số lượng pixel lớn nhất
    dominant_index = np.argmax(counts)
    
    # Lấy màu đặc trưng từ trung tâm cụm có số lượng pixel lớn nhất
    dominant_color = kmeans.cluster_centers_[dominant_index].astype(int)
    
    return dominant_color

def visualize_color(rgb_values):
    # Tạo một hình ảnh với một pixel màu RGB được chỉ định
    color_image = [[rgb_values]]

    # Hiển thị hình ảnh
    plt.imshow(color_image)
    plt.axis('off')
    plt.show()


start = time.time()
for img in image_data:
    print(img)
    img_link = image_path + "/" + img
    image = cv2.imread(img_link)
    # cv2.imshow("image", image)

    mask = skin_detector.process(image)
    if mask is not None:
        # Tìm màu đặc trưng
        dominant_color = find_dominant_color(image, mask)
        print(dominant_color)
                    
        # visualize_color(dominant_color)

        # Allot the actual skinTone to a certain shade
        allotedSkinToneVal = allotSkinTone.allotSkin(dominant_color)

        print(f"\033[91mImage: {img}. PREDICT: {allotedSkinToneVal}. LABEL: {label_map[img]}. COUNT: {count}\033[0m")
        diffusion_matrix[label_map[img]][allotedSkinToneVal]+=1
        
        
        count+=1
        if count==1000:
            break
    
    print(f"{'':<10}{'Dark':<10}{'Mid-Dark':<10}{'Mid-Light':<10}{'Light':<10}")
    print(f"{'Dark':<10}{diffusion_matrix['dark']['dark']:<10}{diffusion_matrix['dark']['mid-dark']:<10}{diffusion_matrix['dark']['mid-light']:<10}{diffusion_matrix['dark']['light']:<10}")
    print(f"{'Mid-Dark':<10}{diffusion_matrix['mid-dark']['dark']:<10}{diffusion_matrix['mid-dark']['mid-dark']:<10}{diffusion_matrix['mid-dark']['mid-light']:<10}{diffusion_matrix['mid-dark']['light']:<10}")
    print(f"{'Mid-Light':<10}{diffusion_matrix['mid-light']['dark']:<10}{diffusion_matrix['mid-light']['mid-dark']:<10}{diffusion_matrix['mid-light']['mid-light']:<10}{diffusion_matrix['mid-light']['light']:<10}")
    print(f"{'Light':<10}{diffusion_matrix['light']['dark']:<10}{diffusion_matrix['light']['mid-dark']:<10}{diffusion_matrix['light']['mid-light']:<10}{diffusion_matrix['light']['light']:<10}")
    print(f"Accuracy: {(diffusion_matrix['dark']['dark'] + diffusion_matrix['mid-dark']['mid-dark'] + diffusion_matrix['mid-light']['mid-light'] + diffusion_matrix['light']['light']) / count}")

finish = time.time()
print(f"Time: {finish - start}")
# Out:
# image_4780.jpg
# [137 110  86]
# Image: image_4780.jpg. PREDICT: mid-light. LABEL: mid-light. COUNT: 0
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         0         0
# Mid-Light 0         0         1         0
# Light     0         0         0         0
# Accuracy: 1.0
# image_4794.jpg
# [234 180 163]
# Image: image_4794.jpg. PREDICT: light. LABEL: light. COUNT: 1
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         0         0
# Mid-Light 0         0         1         0
# Light     0         0         0         1
# Accuracy: 1.0
# 53829219.jpg
# [158 133 118]
# Image: 53829219.jpg. PREDICT: mid-light. LABEL: mid-light. COUNT: 2
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         0         0
# Mid-Light 0         0         2         0
# Light     0         0         0         1
# Accuracy: 1.0
# 41260125.jpg
# [125 144 156]
# Image: 41260125.jpg. PREDICT: mid-light. LABEL: light. COUNT: 3
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         0         0
# Mid-Light 0         0         2         0
# Light     0         0         1         1
# Accuracy: 0.75
# 81106588.jpg
# [220 202 174]
# Image: 81106588.jpg. PREDICT: light. LABEL: mid-light. COUNT: 4
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         0         0
# Mid-Light 0         0         2         1
# Light     0         0         1         1
# Accuracy: 0.6
# 74086382.jpg
# [246 215 193]
# Image: 74086382.jpg. PREDICT: light. LABEL: light. COUNT: 5
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         0         0
# Mid-Light 0         0         2         1
# Light     0         0         1         2
# Accuracy: 0.6666666666666666
# 95475963.jpg
# [213 168 143]
# Image: 95475963.jpg. PREDICT: light. LABEL: light. COUNT: 6
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         0         0
# Mid-Light 0         0         2         1
# Light     0         0         1         3
# Accuracy: 0.7142857142857143
# 46673174.jpg
# [131  98  77]
# Image: 46673174.jpg. PREDICT: mid-light. LABEL: light. COUNT: 7
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         0         0
# Mid-Light 0         0         2         1
# Light     0         0         2         3
# Accuracy: 0.625
# 10097785.jpg
# [183 155 140]
# Image: 10097785.jpg. PREDICT: light. LABEL: light. COUNT: 8
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         0         0
# Mid-Light 0         0         2         1
# Light     0         0         2         4
# Accuracy: 0.6666666666666666
# 69768682.jpg
# [188 140 117]
# Image: 69768682.jpg. PREDICT: mid-light. LABEL: light. COUNT: 9
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         0         0
# Mid-Light 0         0         2         1
# Light     0         0         3         4
# Accuracy: 0.6
# 41333455.jpg
# [164 165 141]
# Image: 41333455.jpg. PREDICT: light. LABEL: light. COUNT: 10
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         0         0
# Mid-Light 0         0         2         1
# Light     0         0         3         5
# Accuracy: 0.6363636363636364
# 53648904.jpg
# [133 115  83]
# Image: 53648904.jpg. PREDICT: mid-light. LABEL: mid-light. COUNT: 11
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         0         0
# Mid-Light 0         0         3         1
# Light     0         0         3         5
# Accuracy: 0.6666666666666666
# 74736569.jpg
# [190 149 120]
# Image: 74736569.jpg. PREDICT: light. LABEL: light. COUNT: 12
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         0         0
# Mid-Light 0         0         3         1
# Light     0         0         3         6
# Accuracy: 0.6923076923076923
# image_6435.jpg
# [196 128 100]
# Image: image_6435.jpg. PREDICT: mid-light. LABEL: mid-light. COUNT: 13
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         0         0
# Mid-Light 0         0         4         1
# Light     0         0         3         6
# Accuracy: 0.7142857142857143
# 2320904.jpg
# [146  82  61]
# Image: 2320904.jpg. PREDICT: mid-light. LABEL: light. COUNT: 14
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         0         0
# Mid-Light 0         0         4         1
# Light     0         0         4         6
# Accuracy: 0.6666666666666666
# 48740420.jpg
# [217 180 164]
# Image: 48740420.jpg. PREDICT: light. LABEL: light. COUNT: 15
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         0         0
# Mid-Light 0         0         4         1
# Light     0         0         4         7
# Accuracy: 0.6875
# 46576715.jpg
# [234 202 179]
# Image: 46576715.jpg. PREDICT: light. LABEL: light. COUNT: 16
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         0         0
# Mid-Light 0         0         4         1
# Light     0         0         4         8
# Accuracy: 0.7058823529411765
# 76659122.jpg
# [156 137 117]
# Image: 76659122.jpg. PREDICT: mid-light. LABEL: mid-light. COUNT: 17
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         0         0
# Mid-Light 0         0         5         1
# Light     0         0         4         8
# Accuracy: 0.7222222222222222
# 75921137.jpg
# [216 193 172]
# Image: 75921137.jpg. PREDICT: light. LABEL: light. COUNT: 18
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         0         0
# Mid-Light 0         0         5         1
# Light     0         0         4         9
# Accuracy: 0.7368421052631579
# 3993303.jpg
# [252 216 121]
# Image: 3993303.jpg. PREDICT: light. LABEL: light. COUNT: 19
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         0         0
# Mid-Light 0         0         5         1
# Light     0         0         4         10
# Accuracy: 0.75
# image_2500.jpg
# [148 100  77]
# Image: image_2500.jpg. PREDICT: mid-light. LABEL: mid-dark. COUNT: 20
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         1         0
# Mid-Light 0         0         5         1
# Light     0         0         4         10
# Accuracy: 0.7142857142857143
# 95476029.jpg
# [186 151 120]
# Image: 95476029.jpg. PREDICT: mid-light. LABEL: light. COUNT: 21
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         1         0
# Mid-Light 0         0         5         1
# Light     0         0         5         10
# Accuracy: 0.6818181818181818
# 77442820.jpg
# [229 209 189]
# Image: 77442820.jpg. PREDICT: light. LABEL: light. COUNT: 22
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         1         0
# Mid-Light 0         0         5         1
# Light     0         0         5         11
# Accuracy: 0.6956521739130435
# 75105580.jpg
# [193 132 107]
# Image: 75105580.jpg. PREDICT: mid-light. LABEL: mid-light. COUNT: 23
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         1         0
# Mid-Light 0         0         6         1
# Light     0         0         5         11
# Accuracy: 0.7083333333333334
# 84849485.jpg
# [172 141 126]
# Image: 84849485.jpg. PREDICT: mid-light. LABEL: mid-dark. COUNT: 24
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         2         0
# Mid-Light 0         0         6         1
# Light     0         0         5         11
# Accuracy: 0.68
# 84553213.jpg
# [188 138 120]
# Image: 84553213.jpg. PREDICT: mid-light. LABEL: light. COUNT: 25
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         2         0
# Mid-Light 0         0         6         1
# Light     0         0         6         11
# Accuracy: 0.6538461538461539
# 65513658.jpg
# [215 185 168]
# Image: 65513658.jpg. PREDICT: light. LABEL: light. COUNT: 26
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         2         0
# Mid-Light 0         0         6         1
# Light     0         0         6         12
# Accuracy: 0.6666666666666666
# 2960295.jpg
# [138 132 103]
# Image: 2960295.jpg. PREDICT: mid-light. LABEL: light. COUNT: 27
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         2         0
# Mid-Light 0         0         6         1
# Light     0         0         7         12
# Accuracy: 0.6428571428571429
# 50222115.jpg
# [200 159 137]
# Image: 50222115.jpg. PREDICT: light. LABEL: mid-light. COUNT: 28
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         2         0
# Mid-Light 0         0         6         2
# Light     0         0         7         12
# Accuracy: 0.6206896551724138
# 83673047.jpg
# [241 197 173]
# Image: 83673047.jpg. PREDICT: light. LABEL: light. COUNT: 29
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         2         0
# Mid-Light 0         0         6         2
# Light     0         0         7         13
# Accuracy: 0.6333333333333333
# 95800049.jpg
# [134 106  84]
# Image: 95800049.jpg. PREDICT: mid-light. LABEL: mid-light. COUNT: 30
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         2         0
# Mid-Light 0         0         7         2
# Light     0         0         7         13
# Accuracy: 0.6451612903225806
# 69444186.jpg
# [212 214 201]
# Image: 69444186.jpg. PREDICT: light. LABEL: light. COUNT: 31
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         2         0
# Mid-Light 0         0         7         2
# Light     0         0         7         14
# Accuracy: 0.65625
# 54131877.jpg
# [251 217 189]
# Image: 54131877.jpg. PREDICT: light. LABEL: light. COUNT: 32
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         2         0
# Mid-Light 0         0         7         2
# Light     0         0         7         15
# Accuracy: 0.6666666666666666
# 10399722.jpg
# [141 127 109]
# Image: 10399722.jpg. PREDICT: mid-light. LABEL: light. COUNT: 33
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         2         0
# Mid-Light 0         0         7         2
# Light     0         0         8         15
# Accuracy: 0.6470588235294118
# 76493215.jpg
# [177 151 123]
# Image: 76493215.jpg. PREDICT: mid-light. LABEL: light. COUNT: 34
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         2         0
# Mid-Light 0         0         7         2
# Light     0         0         9         15
# Accuracy: 0.6285714285714286
# image_2793.jpg
# [171 136 107]
# Image: image_2793.jpg. PREDICT: mid-light. LABEL: light. COUNT: 35
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         2         0
# Mid-Light 0         0         7         2
# Light     0         0         10        15
# Accuracy: 0.6111111111111112
# 86065063.jpg
# [136 106  86]
# Image: 86065063.jpg. PREDICT: mid-light. LABEL: mid-light. COUNT: 36
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         2         0
# Mid-Light 0         0         8         2
# Light     0         0         10        15
# Accuracy: 0.6216216216216216
# 83493294.jpg
# [237 200 173]
# Image: 83493294.jpg. PREDICT: light. LABEL: light. COUNT: 37
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         2         0
# Mid-Light 0         0         8         2
# Light     0         0         10        16
# Accuracy: 0.631578947368421
# image_422.jpg
# [182 129 112]
# Image: image_422.jpg. PREDICT: mid-light. LABEL: light. COUNT: 38
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         2         0
# Mid-Light 0         0         8         2
# Light     0         0         11        16
# Accuracy: 0.6153846153846154
# 6943210.jpg
# [220 196 170]
# Image: 6943210.jpg. PREDICT: light. LABEL: mid-light. COUNT: 39
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         2         0
# Mid-Light 0         0         8         3
# Light     0         0         11        16
# Accuracy: 0.6
# 45028770.jpg
# [252 211 188]
# Image: 45028770.jpg. PREDICT: light. LABEL: light. COUNT: 40
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         2         0
# Mid-Light 0         0         8         3
# Light     0         0         11        17
# Accuracy: 0.6097560975609756
# 50295391.jpg
# [212 178 156]
# Image: 50295391.jpg. PREDICT: light. LABEL: light. COUNT: 41
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         2         0
# Mid-Light 0         0         8         3
# Light     0         0         11        18
# Accuracy: 0.6190476190476191
# 99049208.jpg
# [242 202 180]
# Image: 99049208.jpg. PREDICT: light. LABEL: light. COUNT: 42
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         2         0
# Mid-Light 0         0         8         3
# Light     0         0         11        19
# Accuracy: 0.627906976744186
# 42734456.jpg
# [154 119  97]
# Image: 42734456.jpg. PREDICT: mid-light. LABEL: mid-light. COUNT: 43
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         2         0
# Mid-Light 0         0         9         3
# Light     0         0         11        19
# Accuracy: 0.6363636363636364
# 75104384.jpg
# [151 103  88]
# Image: 75104384.jpg. PREDICT: mid-light. LABEL: mid-light. COUNT: 44
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         2         0
# Mid-Light 0         0         10        3
# Light     0         0         11        19
# Accuracy: 0.6444444444444445
# 3464075.jpg
# [225 204 170]
# Image: 3464075.jpg. PREDICT: light. LABEL: light. COUNT: 45
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         2         0
# Mid-Light 0         0         10        3
# Light     0         0         11        20
# Accuracy: 0.6521739130434783
# image_5592.jpg
# [144  95  81]
# Image: image_5592.jpg. PREDICT: mid-light. LABEL: light. COUNT: 46
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         2         0
# Mid-Light 0         0         10        3
# Light     0         0         12        20
# Accuracy: 0.6382978723404256
# 85228027.jpg
# [209 182 160]
# Image: 85228027.jpg. PREDICT: light. LABEL: light. COUNT: 47
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         2         0
# Mid-Light 0         0         10        3
# Light     0         0         12        21
# Accuracy: 0.6458333333333334
# 71990492.jpg
# [191 165 142]
# Image: 71990492.jpg. PREDICT: light. LABEL: light. COUNT: 48
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         2         0
# Mid-Light 0         0         10        3
# Light     0         0         12        22
# Accuracy: 0.6530612244897959
# 45750289.jpg
# [126 103  72]
# Image: 45750289.jpg. PREDICT: mid-light. LABEL: light. COUNT: 49
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         2         0
# Mid-Light 0         0         10        3
# Light     0         0         13        22
# Accuracy: 0.64
# 55283718.jpg
# [225 200 177]
# Image: 55283718.jpg. PREDICT: light. LABEL: light. COUNT: 50
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         2         0
# Mid-Light 0         0         10        3
# Light     0         0         13        23
# Accuracy: 0.6470588235294118
# 72118098.jpg
# [192 141 121]
# Image: 72118098.jpg. PREDICT: mid-light. LABEL: mid-dark. COUNT: 51
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         3         0
# Mid-Light 0         0         10        3
# Light     0         0         13        23
# Accuracy: 0.6346153846153846
# 82770051.jpg
# [238 202 185]
# Image: 82770051.jpg. PREDICT: light. LABEL: light. COUNT: 52
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         3         0
# Mid-Light 0         0         10        3
# Light     0         0         13        24
# Accuracy: 0.6415094339622641
# 83831388.jpg
# [205 204 160]
# Image: 83831388.jpg. PREDICT: light. LABEL: light. COUNT: 53
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         3         0
# Mid-Light 0         0         10        3
# Light     0         0         13        25
# Accuracy: 0.6481481481481481
# 61812928.jpg
# [239 197 167]
# Image: 61812928.jpg. PREDICT: light. LABEL: mid-light. COUNT: 54
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         3         0
# Mid-Light 0         0         10        4
# Light     0         0         13        25
# Accuracy: 0.6363636363636364
# 54224165.jpg
# [211 160 120]
# Image: 54224165.jpg. PREDICT: light. LABEL: light. COUNT: 55
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         3         0
# Mid-Light 0         0         10        4
# Light     0         0         13        26
# Accuracy: 0.6428571428571429
# 44860084.jpg
# [199 152 111]
# Image: 44860084.jpg. PREDICT: light. LABEL: mid-light. COUNT: 56
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         3         0
# Mid-Light 0         0         10        5
# Light     0         0         13        26
# Accuracy: 0.631578947368421
# image_1086.jpg
# [137 102  90]
# Image: image_1086.jpg. PREDICT: mid-light. LABEL: light. COUNT: 57
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         3         0
# Mid-Light 0         0         10        5
# Light     0         0         14        26
# Accuracy: 0.6206896551724138
# 69066457.jpg
# [226 182 156]
# Image: 69066457.jpg. PREDICT: light. LABEL: light. COUNT: 58
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         3         0
# Mid-Light 0         0         10        5
# Light     0         0         14        27
# Accuracy: 0.6271186440677966
# 74651295.jpg
# [235 198 170]
# Image: 74651295.jpg. PREDICT: light. LABEL: light. COUNT: 59
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         3         0
# Mid-Light 0         0         10        5
# Light     0         0         14        28
# Accuracy: 0.6333333333333333
# 22122350.jpg
# [226 204 193]
# Image: 22122350.jpg. PREDICT: light. LABEL: light. COUNT: 60
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         3         0
# Mid-Light 0         0         10        5
# Light     0         0         14        29
# Accuracy: 0.639344262295082
# 72355557.jpg
# [127 108  83]
# Image: 72355557.jpg. PREDICT: mid-light. LABEL: mid-light. COUNT: 61
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         3         0
# Mid-Light 0         0         11        5
# Light     0         0         14        29
# Accuracy: 0.6451612903225806
# 56709970.jpg
# [202 149 111]
# Image: 56709970.jpg. PREDICT: light. LABEL: light. COUNT: 62
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         3         0
# Mid-Light 0         0         11        5
# Light     0         0         14        30
# Accuracy: 0.6507936507936508
# 66935279.jpg
# [140 105  92]
# Image: 66935279.jpg. PREDICT: mid-light. LABEL: mid-dark. COUNT: 63
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         4         0
# Mid-Light 0         0         11        5
# Light     0         0         14        30
# Accuracy: 0.640625
# 81078820.jpg
# [229 194 171]
# Image: 81078820.jpg. PREDICT: light. LABEL: light. COUNT: 64
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         4         0
# Mid-Light 0         0         11        5
# Light     0         0         14        31
# Accuracy: 0.6461538461538462
# 105711016.jpg
# [128 111  86]
# Image: 105711016.jpg. PREDICT: mid-light. LABEL: mid-dark. COUNT: 65
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         5         0
# Mid-Light 0         0         11        5
# Light     0         0         14        31
# Accuracy: 0.6363636363636364
# 48824284.jpg
# [191 152 122]
# Image: 48824284.jpg. PREDICT: light. LABEL: light. COUNT: 66
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         5         0
# Mid-Light 0         0         11        5
# Light     0         0         14        32
# Accuracy: 0.6417910447761194
# image_9113.jpg
# [164 138 102]
# Image: image_9113.jpg. PREDICT: mid-light. LABEL: light. COUNT: 67
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         5         0
# Mid-Light 0         0         11        5
# Light     0         0         15        32
# Accuracy: 0.6323529411764706
# 38568631.jpg
# [238 201 186]
# Image: 38568631.jpg. PREDICT: light. LABEL: light. COUNT: 68
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         5         0
# Mid-Light 0         0         11        5
# Light     0         0         15        33
# Accuracy: 0.6376811594202898
# 65442044.jpg
# [163 139 117]
# Image: 65442044.jpg. PREDICT: mid-light. LABEL: mid-light. COUNT: 69
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         5         0
# Mid-Light 0         0         12        5
# Light     0         0         15        33
# Accuracy: 0.6428571428571429
# 87769173.jpg
# [201 161 133]
# Image: 87769173.jpg. PREDICT: light. LABEL: light. COUNT: 70
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         5         0
# Mid-Light 0         0         12        5
# Light     0         0         15        34
# Accuracy: 0.647887323943662
# 77409232.jpg
# [192 159 139]
# Image: 77409232.jpg. PREDICT: light. LABEL: mid-light. COUNT: 71
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         5         0
# Mid-Light 0         0         12        6
# Light     0         0         15        34
# Accuracy: 0.6388888888888888
# 5867129.jpg
# [131 152 101]
# Image: 5867129.jpg. PREDICT: mid-light. LABEL: light. COUNT: 72
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         5         0
# Mid-Light 0         0         12        6
# Light     0         0         16        34
# Accuracy: 0.6301369863013698
# 20338937.jpg
# [237 195 178]
# Image: 20338937.jpg. PREDICT: light. LABEL: light. COUNT: 73
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         5         0
# Mid-Light 0         0         12        6
# Light     0         0         16        35
# Accuracy: 0.6351351351351351
# 10024034.jpg
# [236 199 178]
# Image: 10024034.jpg. PREDICT: light. LABEL: light. COUNT: 74
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         5         0
# Mid-Light 0         0         12        6
# Light     0         0         16        36
# Accuracy: 0.64
# 78215298.jpg
# [198 157 132]
# Image: 78215298.jpg. PREDICT: light. LABEL: light. COUNT: 75
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         5         0
# Mid-Light 0         0         12        6
# Light     0         0         16        37
# Accuracy: 0.6447368421052632
# 66852527.jpg
# [222 194 169]
# Image: 66852527.jpg. PREDICT: light. LABEL: light. COUNT: 76
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         5         0
# Mid-Light 0         0         12        6
# Light     0         0         16        38
# Accuracy: 0.6493506493506493
# 91752484.jpg
# [213 198 172]
# Image: 91752484.jpg. PREDICT: light. LABEL: light. COUNT: 77
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         0
# Mid-Dark  0         0         5         0
# Mid-Light 0         0         12        6
# Light     0         0         16        39
# Accuracy: 0.6538461538461539
# 76008328.jpg
# [135 196 208]
# Image: 76008328.jpg. PREDICT: light. LABEL: dark. COUNT: 78
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         1
# Mid-Dark  0         0         5         0
# Mid-Light 0         0         12        6
# Light     0         0         16        39
# Accuracy: 0.6455696202531646
# 57672273.jpg
# [247 181 161]
# Image: 57672273.jpg. PREDICT: light. LABEL: light. COUNT: 79
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         1
# Mid-Dark  0         0         5         0
# Mid-Light 0         0         12        6
# Light     0         0         16        40
# Accuracy: 0.65
# image_10109.jpg
# [195 143 118]
# Image: image_10109.jpg. PREDICT: mid-light. LABEL: light. COUNT: 80
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         0         1
# Mid-Dark  0         0         5         0
# Mid-Light 0         0         12        6
# Light     0         0         17        40
# Accuracy: 0.6419753086419753
# 59024565.jpg
# [161 142 106]
# Image: 59024565.jpg. PREDICT: mid-light. LABEL: dark. COUNT: 81
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         1         1
# Mid-Dark  0         0         5         0
# Mid-Light 0         0         12        6
# Light     0         0         17        40
# Accuracy: 0.6341463414634146
# 31918601.jpg
# [206 149 118]
# Image: 31918601.jpg. PREDICT: light. LABEL: light. COUNT: 82
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         1         1
# Mid-Dark  0         0         5         0
# Mid-Light 0         0         12        6
# Light     0         0         17        41
# Accuracy: 0.6385542168674698
# 74984206.jpg
# [173 130 102]
# Image: 74984206.jpg. PREDICT: mid-light. LABEL: dark. COUNT: 83
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         2         1
# Mid-Dark  0         0         5         0
# Mid-Light 0         0         12        6
# Light     0         0         17        41
# Accuracy: 0.6309523809523809
# 97633961.jpg
# [120 105  83]
# Image: 97633961.jpg. PREDICT: mid-light. LABEL: mid-light. COUNT: 84
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         2         1
# Mid-Dark  0         0         5         0
# Mid-Light 0         0         13        6
# Light     0         0         17        41
# Accuracy: 0.6352941176470588
# 63441101.jpg
# [231 193 170]
# Image: 63441101.jpg. PREDICT: light. LABEL: light. COUNT: 85
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         2         1
# Mid-Dark  0         0         5         0
# Mid-Light 0         0         13        6
# Light     0         0         17        42
# Accuracy: 0.6395348837209303
# 76515623.jpg
# [214 179 163]
# Image: 76515623.jpg. PREDICT: light. LABEL: mid-light. COUNT: 86
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         2         1
# Mid-Dark  0         0         5         0
# Mid-Light 0         0         13        7
# Light     0         0         17        42
# Accuracy: 0.632183908045977
# 72095581.jpg
# [201 163 141]
# Image: 72095581.jpg. PREDICT: light. LABEL: light. COUNT: 87
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         2         1
# Mid-Dark  0         0         5         0
# Mid-Light 0         0         13        7
# Light     0         0         17        43
# Accuracy: 0.6363636363636364
# 32730786.jpg
# [194 167 144]
# Image: 32730786.jpg. PREDICT: light. LABEL: light. COUNT: 88
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         2         1
# Mid-Dark  0         0         5         0
# Mid-Light 0         0         13        7
# Light     0         0         17        44
# Accuracy: 0.6404494382022472
# image_4834.jpg
# [247 208 178]
# Image: image_4834.jpg. PREDICT: light. LABEL: light. COUNT: 89
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         2         1
# Mid-Dark  0         0         5         0
# Mid-Light 0         0         13        7
# Light     0         0         17        45
# Accuracy: 0.6444444444444445
# 95017619.jpg
# [158 128  99]
# Image: 95017619.jpg. PREDICT: mid-light. LABEL: light. COUNT: 90
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         2         1
# Mid-Dark  0         0         5         0
# Mid-Light 0         0         13        7
# Light     0         0         18        45
# Accuracy: 0.6373626373626373
# 90602182.jpg
# [155 143 118]
# Image: 90602182.jpg. PREDICT: mid-light. LABEL: mid-light. COUNT: 91
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         2         1
# Mid-Dark  0         0         5         0
# Mid-Light 0         0         14        7
# Light     0         0         18        45
# Accuracy: 0.6413043478260869
# 91599082.jpg
# [123 140 160]
# Image: 91599082.jpg. PREDICT: mid-light. LABEL: dark. COUNT: 92
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         3         1
# Mid-Dark  0         0         5         0
# Mid-Light 0         0         14        7
# Light     0         0         18        45
# Accuracy: 0.6344086021505376
# image_9359.jpg
# [190 147 133]
# Image: image_9359.jpg. PREDICT: light. LABEL: light. COUNT: 93
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         3         1
# Mid-Dark  0         0         5         0
# Mid-Light 0         0         14        7
# Light     0         0         18        46
# Accuracy: 0.6382978723404256
# 1121885.jpg
# [184 203 237]
# Image: 1121885.jpg. PREDICT: light. LABEL: light. COUNT: 94
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         3         1
# Mid-Dark  0         0         5         0
# Mid-Light 0         0         14        7
# Light     0         0         18        47
# Accuracy: 0.6421052631578947
# 7075067.jpg
# [225 205 187]
# Image: 7075067.jpg. PREDICT: light. LABEL: light. COUNT: 95
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         3         1
# Mid-Dark  0         0         5         0
# Mid-Light 0         0         14        7
# Light     0         0         18        48
# Accuracy: 0.6458333333333334
# image_3161.jpg
# [212 174 158]
# Image: image_3161.jpg. PREDICT: light. LABEL: light. COUNT: 96
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         3         1
# Mid-Dark  0         0         5         0
# Mid-Light 0         0         14        7
# Light     0         0         18        49
# Accuracy: 0.6494845360824743
# 66007778.jpg
# [153 117  91]
# Image: 66007778.jpg. PREDICT: mid-light. LABEL: light. COUNT: 97
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         3         1
# Mid-Dark  0         0         5         0
# Mid-Light 0         0         14        7
# Light     0         0         19        49
# Accuracy: 0.6428571428571429
# 81336191.jpg
# [136 153 180]
# Image: 81336191.jpg. PREDICT: light. LABEL: light. COUNT: 98
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         3         1
# Mid-Dark  0         0         5         0
# Mid-Light 0         0         14        7
# Light     0         0         19        50
# Accuracy: 0.6464646464646465
# 44250404.jpg
# [228 175 157]
# Image: 44250404.jpg. PREDICT: light. LABEL: light. COUNT: 99
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         3         1
# Mid-Dark  0         0         5         0
# Mid-Light 0         0         14        7
# Light     0         0         19        51
# Accuracy: 0.65
# 69400238.jpg
# [171 171 132]
# Image: 69400238.jpg. PREDICT: light. LABEL: light. COUNT: 100
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         3         1
# Mid-Dark  0         0         5         0
# Mid-Light 0         0         14        7
# Light     0         0         19        52
# Accuracy: 0.6534653465346535
# 28088156.jpg
# [190 150 135]
# Image: 28088156.jpg. PREDICT: light. LABEL: light. COUNT: 101
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         3         1
# Mid-Dark  0         0         5         0
# Mid-Light 0         0         14        7
# Light     0         0         19        53
# Accuracy: 0.6568627450980392
# 64775664.jpg
# [176 141 119]
# Image: 64775664.jpg. PREDICT: mid-light. LABEL: light. COUNT: 102
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         3         1
# Mid-Dark  0         0         5         0
# Mid-Light 0         0         14        7
# Light     0         0         20        53
# Accuracy: 0.6504854368932039
# 106371263.jpg
# [205 187 161]
# Image: 106371263.jpg. PREDICT: light. LABEL: light. COUNT: 103
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         3         1
# Mid-Dark  0         0         5         0
# Mid-Light 0         0         14        7
# Light     0         0         20        54
# Accuracy: 0.6538461538461539
# image_826.jpg
# [231 180 162]
# Image: image_826.jpg. PREDICT: light. LABEL: light. COUNT: 104
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         3         1
# Mid-Dark  0         0         5         0
# Mid-Light 0         0         14        7
# Light     0         0         20        55
# Accuracy: 0.6571428571428571
# 65898103.jpg
# [188 158 135]
# Image: 65898103.jpg. PREDICT: light. LABEL: light. COUNT: 105
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         3         1
# Mid-Dark  0         0         5         0
# Mid-Light 0         0         14        7
# Light     0         0         20        56
# Accuracy: 0.660377358490566
# image_2309.jpg
# [181 120 100]
# Image: image_2309.jpg. PREDICT: mid-light. LABEL: light. COUNT: 106
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         3         1
# Mid-Dark  0         0         5         0
# Mid-Light 0         0         14        7
# Light     0         0         21        56
# Accuracy: 0.6542056074766355
# 66778478.jpg
# [158 195 110]
# Image: 66778478.jpg. PREDICT: light. LABEL: mid-light. COUNT: 107
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         3         1
# Mid-Dark  0         0         5         0
# Mid-Light 0         0         14        8
# Light     0         0         21        56
# Accuracy: 0.6481481481481481
# 65403994.jpg
# [169 157 107]
# Image: 65403994.jpg. PREDICT: mid-light. LABEL: light. COUNT: 108
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         3         1
# Mid-Dark  0         0         5         0
# Mid-Light 0         0         14        8
# Light     0         0         22        56
# Accuracy: 0.6422018348623854
# 5419629.jpg
# [205 182 132]
# Image: 5419629.jpg. PREDICT: light. LABEL: light. COUNT: 109
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         3         1
# Mid-Dark  0         0         5         0
# Mid-Light 0         0         14        8
# Light     0         0         22        57
# Accuracy: 0.6454545454545455
# 106425102.jpg
# [126 145 167]
# Image: 106425102.jpg. PREDICT: mid-light. LABEL: light. COUNT: 110
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         3         1
# Mid-Dark  0         0         5         0
# Mid-Light 0         0         14        8
# Light     0         0         23        57
# Accuracy: 0.6396396396396397
# image_7733.jpg
# [158 120 107]
# Image: image_7733.jpg. PREDICT: mid-light. LABEL: mid-light. COUNT: 111
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         3         1
# Mid-Dark  0         0         5         0
# Mid-Light 0         0         15        8
# Light     0         0         23        57
# Accuracy: 0.6428571428571429
# 85955825.jpg
# [241 219 139]
# Image: 85955825.jpg. PREDICT: light. LABEL: light. COUNT: 112
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         3         1
# Mid-Dark  0         0         5         0
# Mid-Light 0         0         15        8
# Light     0         0         23        58
# Accuracy: 0.6460176991150443
# 88773809.jpg
# [154 202 227]
# Image: 88773809.jpg. PREDICT: light. LABEL: light. COUNT: 113
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         3         1
# Mid-Dark  0         0         5         0
# Mid-Light 0         0         15        8
# Light     0         0         23        59
# Accuracy: 0.6491228070175439
# 72227243.jpg
# [190 165 126]
# Image: 72227243.jpg. PREDICT: light. LABEL: light. COUNT: 114
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         3         1
# Mid-Dark  0         0         5         0
# Mid-Light 0         0         15        8
# Light     0         0         23        60
# Accuracy: 0.6521739130434783
# 67249137.jpg
# [146 143 127]
# Image: 67249137.jpg. PREDICT: mid-light. LABEL: mid-light. COUNT: 115
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         3         1
# Mid-Dark  0         0         5         0
# Mid-Light 0         0         16        8
# Light     0         0         23        60
# Accuracy: 0.6551724137931034
# image_1122.jpg
# [170 150 118]
# Image: image_1122.jpg. PREDICT: mid-light. LABEL: light. COUNT: 116
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         3         1
# Mid-Dark  0         0         5         0
# Mid-Light 0         0         16        8
# Light     0         0         24        60
# Accuracy: 0.6495726495726496
# 7307044.jpg
# [192 162 134]
# Image: 7307044.jpg. PREDICT: light. LABEL: light. COUNT: 117
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         3         1
# Mid-Dark  0         0         5         0
# Mid-Light 0         0         16        8
# Light     0         0         24        61
# Accuracy: 0.652542372881356
# 46030565.jpg
# [175 124  99]
# Image: 46030565.jpg. PREDICT: mid-light. LABEL: mid-dark. COUNT: 118
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         3         1
# Mid-Dark  0         0         6         0
# Mid-Light 0         0         16        8
# Light     0         0         24        61
# Accuracy: 0.6470588235294118
# 68434886.jpg
# [138 109  76]
# Image: 68434886.jpg. PREDICT: mid-light. LABEL: light. COUNT: 119
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         3         1
# Mid-Dark  0         0         6         0
# Mid-Light 0         0         16        8
# Light     0         0         25        61
# Accuracy: 0.6416666666666667
# 82369617.jpg
# [223 171 142]
# Image: 82369617.jpg. PREDICT: light. LABEL: light. COUNT: 120
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         3         1
# Mid-Dark  0         0         6         0
# Mid-Light 0         0         16        8
# Light     0         0         25        62
# Accuracy: 0.6446280991735537
# 42873448.jpg
# [209 157 126]
# Image: 42873448.jpg. PREDICT: light. LABEL: light. COUNT: 121
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         3         1
# Mid-Dark  0         0         6         0
# Mid-Light 0         0         16        8
# Light     0         0         25        63
# Accuracy: 0.6475409836065574
# 77475682.jpg
# [217 195 159]
# Image: 77475682.jpg. PREDICT: light. LABEL: light. COUNT: 122
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         3         1
# Mid-Dark  0         0         6         0
# Mid-Light 0         0         16        8
# Light     0         0         25        64
# Accuracy: 0.6504065040650406
# image_454.jpg
# [146 106  89]
# Image: image_454.jpg. PREDICT: mid-light. LABEL: light. COUNT: 123
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         3         1
# Mid-Dark  0         0         6         0
# Mid-Light 0         0         16        8
# Light     0         0         26        64
# Accuracy: 0.6451612903225806
# 75469521.jpg
# [116 194 231]
# Image: 75469521.jpg. PREDICT: light. LABEL: mid-light. COUNT: 124
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         3         1
# Mid-Dark  0         0         6         0
# Mid-Light 0         0         16        9
# Light     0         0         26        64
# Accuracy: 0.64
# 86214429.jpg
# [143 132 101]
# Image: 86214429.jpg. PREDICT: mid-light. LABEL: mid-light. COUNT: 125
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         3         1
# Mid-Dark  0         0         6         0
# Mid-Light 0         0         17        9
# Light     0         0         26        64
# Accuracy: 0.6428571428571429
# 86638916.jpg
# [249 230 127]
# Image: 86638916.jpg. PREDICT: light. LABEL: mid-light. COUNT: 126
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         3         1
# Mid-Dark  0         0         6         0
# Mid-Light 0         0         17        10
# Light     0         0         26        64
# Accuracy: 0.6377952755905512
# 81609444.jpg
# [131 188 189]
# Image: 81609444.jpg. PREDICT: light. LABEL: light. COUNT: 127
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         3         1
# Mid-Dark  0         0         6         0
# Mid-Light 0         0         17        10
# Light     0         0         26        65
# Accuracy: 0.640625
# 62570150.jpg
# [155  97  72]
# Image: 62570150.jpg. PREDICT: mid-light. LABEL: mid-light. COUNT: 128
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         3         1
# ...
# Light     0         0         197       463
# Accuracy: 0.61337513061651
# 86813694.jpg
# [190 153 125]
# Image: 86813694.jpg. PREDICT: light. LABEL: light. COUNT: 957
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         23        6
# Mid-Dark  0         0         31        13
# Mid-Light 0         0         124       100
# Light     0         0         197       464
# Accuracy: 0.6137787056367432
# 19620398.jpg
# [209 181 162]
# Image: 19620398.jpg. PREDICT: light. LABEL: light. COUNT: 958
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         23        6
# Mid-Dark  0         0         31        13
# Mid-Light 0         0         124       100
# Light     0         0         197       465
# Accuracy: 0.6141814389989573
# 69857574.jpg
# [220 239 139]
# Image: 69857574.jpg. PREDICT: light. LABEL: light. COUNT: 959
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         23        6
# Mid-Dark  0         0         31        13
# Mid-Light 0         0         124       100
# Light     0         0         197       466
# Accuracy: 0.6145833333333334
# image_6267.jpg
# [142 100  88]
# Image: image_6267.jpg. PREDICT: mid-light. LABEL: light. COUNT: 960
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         23        6
# Mid-Dark  0         0         31        13
# Mid-Light 0         0         124       100
# Light     0         0         198       466
# Accuracy: 0.6139438085327783
# 74977032.jpg
# [123 142 159]
# Image: 74977032.jpg. PREDICT: mid-light. LABEL: light. COUNT: 961
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         23        6
# Mid-Dark  0         0         31        13
# Mid-Light 0         0         124       100
# Light     0         0         199       466
# Accuracy: 0.6133056133056133
# 3419339.jpg
# [233 196 173]
# Image: 3419339.jpg. PREDICT: light. LABEL: light. COUNT: 962
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         23        6
# Mid-Dark  0         0         31        13
# Mid-Light 0         0         124       100
# Light     0         0         199       467
# Accuracy: 0.6137071651090342
# 4322127.jpg
# [218 185 170]
# Image: 4322127.jpg. PREDICT: light. LABEL: light. COUNT: 963
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         23        6
# Mid-Dark  0         0         31        13
# Mid-Light 0         0         124       100
# Light     0         0         199       468
# Accuracy: 0.6141078838174274
# image_8560.jpg
# [123 111  86]
# Image: image_8560.jpg. PREDICT: mid-light. LABEL: mid-light. COUNT: 964
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         23        6
# Mid-Dark  0         0         31        13
# Mid-Light 0         0         125       100
# Light     0         0         199       468
# Accuracy: 0.6145077720207254
# image_8333.jpg
# [217 169 140]
# Image: image_8333.jpg. PREDICT: light. LABEL: light. COUNT: 965
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         23        6
# Mid-Dark  0         0         31        13
# Mid-Light 0         0         125       100
# Light     0         0         199       469
# Accuracy: 0.6149068322981367
# 67051100.jpg
# [225 182 155]
# Image: 67051100.jpg. PREDICT: light. LABEL: light. COUNT: 966
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         23        6
# Mid-Dark  0         0         31        13
# Mid-Light 0         0         125       100
# Light     0         0         199       470
# Accuracy: 0.6153050672182007
# 47478919.jpg
# [142  95  69]
# Image: 47478919.jpg. PREDICT: mid-light. LABEL: light. COUNT: 967
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         23        6
# Mid-Dark  0         0         31        13
# Mid-Light 0         0         125       100
# Light     0         0         200       470
# Accuracy: 0.6146694214876033
# 7285311.jpg
# [237 203 159]
# Image: 7285311.jpg. PREDICT: light. LABEL: light. COUNT: 968
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         23        6
# Mid-Dark  0         0         31        13
# Mid-Light 0         0         125       100
# Light     0         0         200       471
# Accuracy: 0.6150670794633643
# 54000885.jpg
# [165 145 115]
# Image: 54000885.jpg. PREDICT: mid-light. LABEL: light. COUNT: 969
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         23        6
# Mid-Dark  0         0         31        13
# Mid-Light 0         0         125       100
# Light     0         0         201       471
# Accuracy: 0.6144329896907217
# image_9941.jpg
# [202 171 155]
# Image: image_9941.jpg. PREDICT: light. LABEL: light. COUNT: 970
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         23        6
# Mid-Dark  0         0         31        13
# Mid-Light 0         0         125       100
# Light     0         0         201       472
# Accuracy: 0.6148300720906282
# 104079852.jpg
# [227 202 167]
# Image: 104079852.jpg. PREDICT: light. LABEL: light. COUNT: 971
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         23        6
# Mid-Dark  0         0         31        13
# Mid-Light 0         0         125       100
# Light     0         0         201       473
# Accuracy: 0.6152263374485597
# 79676683.jpg
# [176 128 101]
# Image: 79676683.jpg. PREDICT: mid-light. LABEL: light. COUNT: 972
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         23        6
# Mid-Dark  0         0         31        13
# Mid-Light 0         0         125       100
# Light     0         0         202       473
# Accuracy: 0.6145940390544707
# 72939534.jpg
# [125 112  84]
# Image: 72939534.jpg. PREDICT: mid-light. LABEL: light. COUNT: 973
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         23        6
# Mid-Dark  0         0         31        13
# Mid-Light 0         0         125       100
# Light     0         0         203       473
# Accuracy: 0.6139630390143738
# 68193087.jpg
# [199 173 152]
# Image: 68193087.jpg. PREDICT: light. LABEL: light. COUNT: 974
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         23        6
# Mid-Dark  0         0         31        13
# Mid-Light 0         0         125       100
# Light     0         0         203       474
# Accuracy: 0.6143589743589744
# 43209899.jpg
# [193 172 138]
# Image: 43209899.jpg. PREDICT: light. LABEL: light. COUNT: 975
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         23        6
# Mid-Dark  0         0         31        13
# Mid-Light 0         0         125       100
# Light     0         0         203       475
# Accuracy: 0.6147540983606558
# 78216435.jpg
# [143 101  83]
# Image: 78216435.jpg. PREDICT: mid-light. LABEL: mid-light. COUNT: 976
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         23        6
# Mid-Dark  0         0         31        13
# Mid-Light 0         0         126       100
# Light     0         0         203       475
# Accuracy: 0.6151484135107472
# 39321030.jpg
# [192 189 165]
# Image: 39321030.jpg. PREDICT: light. LABEL: light. COUNT: 977
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         23        6
# Mid-Dark  0         0         31        13
# Mid-Light 0         0         126       100
# Light     0         0         203       476
# Accuracy: 0.6155419222903885
# 64949938.jpg
# [184 142 107]
# Image: 64949938.jpg. PREDICT: mid-light. LABEL: light. COUNT: 978
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         23        6
# Mid-Dark  0         0         31        13
# Mid-Light 0         0         126       100
# Light     0         0         204       476
# Accuracy: 0.6149131767109295
# 61389311.jpg
# [227 188 169]
# Image: 61389311.jpg. PREDICT: light. LABEL: light. COUNT: 979
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         23        6
# Mid-Dark  0         0         31        13
# Mid-Light 0         0         126       100
# Light     0         0         204       477
# Accuracy: 0.6153061224489796
# 87388894.jpg
# [123 122  71]
# Image: 87388894.jpg. PREDICT: mid-light. LABEL: mid-light. COUNT: 980
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         23        6
# Mid-Dark  0         0         31        13
# Mid-Light 0         0         127       100
# Light     0         0         204       477
# Accuracy: 0.6156982670744139
# image_87.jpg
# [228 187 161]
# Image: image_87.jpg. PREDICT: light. LABEL: mid-light. COUNT: 981
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         23        6
# Mid-Dark  0         0         31        13
# Mid-Light 0         0         127       101
# Light     0         0         204       477
# Accuracy: 0.615071283095723
# image_9425.jpg
# [163 127 110]
# Image: image_9425.jpg. PREDICT: mid-light. LABEL: light. COUNT: 982
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         23        6
# Mid-Dark  0         0         31        13
# Mid-Light 0         0         127       101
# Light     0         0         205       477
# Accuracy: 0.6144455747711088
# 30010602.jpg
# [212 148 117]
# Image: 30010602.jpg. PREDICT: light. LABEL: light. COUNT: 983
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         23        6
# Mid-Dark  0         0         31        13
# Mid-Light 0         0         127       101
# Light     0         0         205       478
# Accuracy: 0.6148373983739838
# 58287966.jpg
# [115  98  82]
# Image: 58287966.jpg. PREDICT: mid-light. LABEL: light. COUNT: 984
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         23        6
# Mid-Dark  0         0         31        13
# Mid-Light 0         0         127       101
# Light     0         0         206       478
# Accuracy: 0.6142131979695431
# image_6209.jpg
# [190 156 136]
# Image: image_6209.jpg. PREDICT: light. LABEL: mid-light. COUNT: 985
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         23        6
# Mid-Dark  0         0         31        13
# Mid-Light 0         0         127       102
# Light     0         0         206       478
# Accuracy: 0.6135902636916836
# 57315057.jpg
# [239 183 148]
# Image: 57315057.jpg. PREDICT: light. LABEL: mid-light. COUNT: 986
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         23        6
# Mid-Dark  0         0         31        13
# Mid-Light 0         0         127       103
# Light     0         0         206       478
# Accuracy: 0.6129685916919959
# image_6289.jpg
# [213 191 165]
# Image: image_6289.jpg. PREDICT: light. LABEL: light. COUNT: 987
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         23        6
# Mid-Dark  0         0         31        13
# Mid-Light 0         0         127       103
# Light     0         0         206       479
# Accuracy: 0.6133603238866396
# 87990182.jpg
# [214 198 174]
# Image: 87990182.jpg. PREDICT: light. LABEL: mid-light. COUNT: 988
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         23        6
# Mid-Dark  0         0         31        13
# Mid-Light 0         0         127       104
# Light     0         0         206       479
# Accuracy: 0.6127401415571284
# 47349069.jpg
# [237 222 174]
# Image: 47349069.jpg. PREDICT: light. LABEL: light. COUNT: 989
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         23        6
# Mid-Dark  0         0         31        13
# Mid-Light 0         0         127       104
# Light     0         0         206       480
# Accuracy: 0.6131313131313131
# 79092707.jpg
# [238 198 182]
# Image: 79092707.jpg. PREDICT: light. LABEL: light. COUNT: 990
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         23        6
# Mid-Dark  0         0         31        13
# Mid-Light 0         0         127       104
# Light     0         0         206       481
# Accuracy: 0.6135216952573158
# 61209755.jpg
# [143 172 111]
# Image: 61209755.jpg. PREDICT: mid-light. LABEL: light. COUNT: 991
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         23        6
# Mid-Dark  0         0         31        13
# Mid-Light 0         0         127       104
# Light     0         0         207       481
# Accuracy: 0.6129032258064516
# image_7318.jpg
# [166 131 109]
# Image: image_7318.jpg. PREDICT: mid-light. LABEL: mid-light. COUNT: 992
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         23        6
# Mid-Dark  0         0         31        13
# Mid-Light 0         0         128       104
# Light     0         0         207       481
# Accuracy: 0.6132930513595166
# 68448170.jpg
# [226 184 168]
# Image: 68448170.jpg. PREDICT: light. LABEL: light. COUNT: 993
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         23        6
# Mid-Dark  0         0         31        13
# Mid-Light 0         0         128       104
# Light     0         0         207       482
# Accuracy: 0.613682092555332
# 1661361.jpg
# [208 188 166]
# Image: 1661361.jpg. PREDICT: light. LABEL: light. COUNT: 994
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         23        6
# Mid-Dark  0         0         31        13
# Mid-Light 0         0         128       104
# Light     0         0         207       483
# Accuracy: 0.614070351758794
# image_677.jpg
# [218 189 165]
# Image: image_677.jpg. PREDICT: light. LABEL: light. COUNT: 995
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         23        6
# Mid-Dark  0         0         31        13
# Mid-Light 0         0         128       104
# Light     0         0         207       484
# Accuracy: 0.6144578313253012
# image_4027.jpg
# [145 100  65]
# Image: image_4027.jpg. PREDICT: mid-light. LABEL: mid-light. COUNT: 996
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         23        6
# Mid-Dark  0         0         31        13
# Mid-Light 0         0         129       104
# Light     0         0         207       484
# Accuracy: 0.6148445336008024
# 64121783.jpg
# [180 157 113]
# Image: 64121783.jpg. PREDICT: mid-light. LABEL: mid-light. COUNT: 997
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         23        6
# Mid-Dark  0         0         31        13
# Mid-Light 0         0         130       104
# Light     0         0         207       484
# Accuracy: 0.6152304609218436
# 68751902.jpg
# [133 170 189]
# Image: 68751902.jpg. PREDICT: light. LABEL: light. COUNT: 998
#           Dark      Mid-Dark  Mid-Light Light
# Dark      0         0         23        6
# Mid-Dark  0         0         31        13
# Mid-Light 0         0         130       104
# Light     0         0         207       485
# Accuracy: 0.6156156156156156
# 83898484.jpg
# [183 164 128]
# Image: 83898484.jpg. PREDICT: light. LABEL: mid-light. COUNT: 999
# Time: 1976.7997694015503
